# %%
# !pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
# WARNING: Ignoring invalid distribution -ffi (c:\python38\lib\site-packages)
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to c:\users\mahi\appdata\local\temp\pip-install-nfqj1vqk\twint_f0b15d5619b64833b8c0332e6144db99
#   Resolved https://github.com/twintproject/twint.git to commit origin/master
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# WARNING: Ignoring invalid distribution -ffi (c:\python38\lib\site-packages)
#   Running command git clone --filter=blob:none -q https://github.com/twintproject/twint.git 'C:\Users\Mahi\AppData\Local\Temp\pip-install-nfqj1vqk\twint_f0b15d5619b64833b8c0332e6144db99'
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# WARNING: Ignoring invalid distribution -ffi (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\python38\lib\site-packages)
# ...

# %%
# %run scrape
# Out:
# salkhanacademy
# 1483886499418443776 2022-01-20 01:08:05 +0530 <salkhanacademy> @opensea @ParallelNFT @khanacademy The proceeds from this NFT auction will empower millions of learners. Thank you @ParallelNFT @opensea
# 1462638122580152327 2021-11-22 09:54:37 +0530 <salkhanacademy> Just saw #dearsanfrancisco. Blew my mind. 10x what I expected.  https://t.co/54pvgzPIyn
# 1441135790113787906 2021-09-24 01:52:02 +0530 <salkhanacademy> On Monday at noon PT, I'm joining San Jose Mayor @sliccardo &amp; @SolutionsSJ1 for a conversation about learning gaps and how to support our children's education this upcoming school year. Register for free:  https://t.co/4rbp1khSQI
# 1438939367859376128 2021-09-18 00:24:14 +0530 <salkhanacademy> Dug this picture up from 2016. Think it could make for a good ratios word problem on @khanacademy  https://t.co/4qLlECblCG
# ...
