# %% [markdown]
# ## Installing and Importing Dependencies

# %%
import pandas as pd
import numpy as np
import json
import re 
import sys
import itertools

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# !pip install spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util

import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.7/dist-packages (2.19.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (2.27.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.0.10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline

# %% [markdown]
# #### Max Display Disable

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %% [markdown]
# ## Importing Dataset of the tracks

# %%
df = pd.read_csv('/content/drive/MyDrive/tracks.csv')
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %% [markdown]
# There is nothing here related to the genre of the song which will be useful. This data alone won't help us find relavent content since this is a content based recommendation system. Fortunately there is a artist.csv file that should have some useful information

# %% [markdown]
# ## Importing Dataset of the artist and genres

# %%
df_genres = pd.read_csv('/content/drive/MyDrive/data_by_artist_o.csv')
df_genres.tail()
# Out:
#                                                   genres artists  \
# 28675                                                 []     麥志誠
# 28676  ['c-pop', 'classic cantopop', 'classic mandopo...     黃品源
# 28677                                                 []     黃國隆
# 28678            ['chinese indie', 'chinese indie rock']      黑豹
# 28679                             ['classic korean pop']     조정현
#
#        acousticness  danceability    duration_ms  energy  instrumentalness  \
# 28675      0.512000      0.356000  198773.000000  0.3060          0.008970
# 28676      0.541000      0.578000  293840.000000  0.3340          0.000006
# 28677      0.785455      0.570818  174582.727273  0.1484          0.000083
# 28678      0.381000      0.353000  316160.000000  0.6860          0.000000
# 28679      0.568000      0.447000  237688.000000  0.2150          0.000001
#
#        liveness   loudness  speechiness       tempo   valence  popularity  \
# 28675  0.108000 -10.119000     0.027700  150.049000  0.328000        35.0
# 28676  0.067500 -11.974000     0.026700  135.934000  0.243000        48.0
# 28677  0.142191 -21.610091     0.054355  119.586273  0.741273        23.0
# 28678  0.056800  -9.103000     0.039500  200.341000  0.352000        35.0
# 28679  0.064900 -16.478000     0.027200   71.979000  0.177000        31.0
#
#        key  mode  count
# 28675   10     1      2
# 28676    9     0      2
# 28677    5     1     11
# 28678   11     1      2
# 28679   10     1      2

# %% [markdown]
# The genres are going to be really useful here and I'll need to use it moving forward. Now, the genre column appears to be in a list format but my past experience tells me that it's likely not. Let's investigate this further.

# %%
df_genres.dtypes
# Out:
# genres               object
# artists              object
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# popularity          float64
# key                   int64
# mode                  int64
# count                 int64
# dtype: object

# %%
df_genres.shape
# Out:
# (28680, 16)

# %%
df.shape
# Out:
# (586672, 20)

# %%
df_genres['genres'].tail()
# Out:
# 28675                                                   []
# 28676    ['c-pop', 'classic cantopop', 'classic mandopo...
# 28677                                                   []
# 28678              ['chinese indie', 'chinese indie rock']
# 28679                               ['classic korean pop']
# Name: genres, dtype: object

# %%
df_genres['genres_upd'] = df_genres['genres'].apply(lambda x:[re.sub(' ', '_', i) for i in re.findall(r"'([^']*)'", x)])

# %%
df_genres['genres_upd'].tail().values[1][0]
# Out:
# 'c-pop'

# %%
# Now, if you recall, this data is at a artist level and the previous dataset is at a song level. So what here's what we need to do:

# Explode artists column in the previous so each artist within a song will have their own row
# Merge data_w_genre to the exploded dataset in Step 1 so that the previous dataset no is enriched with genre dataset

# %%
df['artists_upd_v1'] = df['artists'].apply(lambda x: re.findall(r"'([^']*)'", x))

# %%
df['artists_upd_v1'].values[0]
# Out:
# ['Uli']

# %%
df[df['artists_upd_v1'].apply(lambda x: not x)].head(5)
# Out:
#                          id                     name  popularity  duration_ms  \
# 164  1xEEYhWxT4WhDQdxfPCT8D                Snake Rag          20       194533
# 170  3rauXVLOOM5BlxWqUcDpkg             Chimes Blues          14       170827
# 172  1UdqHVRFYMZKU2Q7xkLtYc     Pickin' On Your Baby          11       197493
# 174  0Vl2DO5U6FjgBpzCtBN3OA  Everybody Loves My Baby          10       152507
# 180  5SvyP1ZeJX1jA7AOZD08NA                    Tears          10       187227
#
#      explicit                             artists                  id_artists  \
# 164         0  ["King Oliver's Creole Jazz Band"]  ['08Zk65toyJllap1MnzljxZ']
# 170         0  ["King Oliver's Creole Jazz Band"]  ['08Zk65toyJllap1MnzljxZ']
# 172         0    ["Clarence Williams' Blue Five"]  ['6RuQvIr0t0otZHnAxXTGkm']
# 174         0    ["Clarence Williams' Blue Five"]  ['6RuQvIr0t0otZHnAxXTGkm']
# 180         0  ["King Oliver's Creole Jazz Band"]  ['08Zk65toyJllap1MnzljxZ']
#
#     release_date  danceability  energy  key  loudness  mode  speechiness  \
# 164         1923         0.708   0.361    0   -11.764     0       0.0441
# 170         1923         0.546   0.189    0   -15.984     1       0.0581
# 172         1923         0.520   0.153    0   -14.042     1       0.0440
# 174         1923         0.514   0.193    2   -13.920     0       0.2380
# 180         1923         0.359   0.357    3   -11.810     1       0.0511
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 164         0.994             0.883     0.103    0.902  105.695
# 170         0.996             0.908     0.339    0.554   80.318
# 172         0.995             0.131     0.353    0.319  102.937
# 174         0.996             0.199     0.248    0.665  180.674
# 180         0.994             0.819     0.290    0.753  205.053
#
#      time_signature artists_upd_v1
# 164               4             []
# 170               4             []
# 172               4             []
# 174               4             []
# 180               4             []

# %%
df['artists_upd_v2'] = df['artists'].apply(lambda x: re.findall('\"(.*?)\"',x))
df['artists_upd'] = np.where(df['artists_upd_v1'].apply(lambda x: not x), df['artists_upd_v2'], df['artists_upd_v1'] )

# %%
for i in range(0, len(df['name'])):
    if type(df['name'][i]) == float:
        df['name'][i]= str(df['name'][i])

# %%
df['artists_song'] = df.apply(lambda row: row['artists_upd'][0]+row['name'],axis = 1)

# %%
df[df['name']=='Adore You']
# Out:
#                            id       name  popularity  duration_ms  explicit  \
# 86217  5AnCLGg35ziFOloEnXK4uu  Adore You          71       278747         0
# 91884  3jjujdWJ72nww5eGnfs2E7  Adore You          88       207133         0
# 92524  1M4qEo4HE3PRaCOM7EXNJq  Adore You          74       207133         0
#
#                 artists                  id_artists release_date  \
# 86217   ['Miley Cyrus']  ['5YGY8feqx7naU7z4HrwZM6']   2013-10-04
# 91884  ['Harry Styles']  ['6KImCVD70vtIoJWnq6nGn3']   2019-12-13
# 92524  ['Harry Styles']  ['6KImCVD70vtIoJWnq6nGn3']   2019-12-06
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 86217         0.583   0.655    0    -5.407     1       0.0315        0.1110
# 91884         0.676   0.771    8    -3.675     1       0.0483        0.0237
# 92524         0.676   0.771    8    -3.675     1       0.0483        0.0237
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 86217          0.000004     0.113    0.201  119.759               4
# 91884          0.000007     0.102    0.569   99.048               4
# 92524          0.000007     0.102    0.569   99.048               4
#
#        artists_upd_v1 artists_upd_v2     artists_upd           artists_song
# 86217   [Miley Cyrus]             []   [Miley Cyrus]   Miley CyrusAdore You
# 91884  [Harry Styles]             []  [Harry Styles]  Harry StylesAdore You
# 92524  [Harry Styles]             []  [Harry Styles]  Harry StylesAdore You

# %%
df.drop_duplicates('artists_song',inplace = True)

# %%
df[df['name']=='Adore You']
# Out:
#                            id       name  popularity  duration_ms  explicit  \
# 86217  5AnCLGg35ziFOloEnXK4uu  Adore You          71       278747         0
# 91884  3jjujdWJ72nww5eGnfs2E7  Adore You          88       207133         0
#
#                 artists                  id_artists release_date  \
# 86217   ['Miley Cyrus']  ['5YGY8feqx7naU7z4HrwZM6']   2013-10-04
# 91884  ['Harry Styles']  ['6KImCVD70vtIoJWnq6nGn3']   2019-12-13
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 86217         0.583   0.655    0    -5.407     1       0.0315        0.1110
# 91884         0.676   0.771    8    -3.675     1       0.0483        0.0237
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 86217          0.000004     0.113    0.201  119.759               4
# 91884          0.000007     0.102    0.569   99.048               4
#
#        artists_upd_v1 artists_upd_v2     artists_upd           artists_song
# 86217   [Miley Cyrus]             []   [Miley Cyrus]   Miley CyrusAdore You
# 91884  [Harry Styles]             []  [Harry Styles]  Harry StylesAdore You

# %%
artists_exploded = df[['artists_upd','id']].explode('artists_upd')

# %%
artists_exploded.head()
# Out:
#        artists_upd                      id
# 0              Uli  35iwgR4jXetI318WEWsa1Q
# 1  Fernando Pessoa  021ht4sdgPcrDgSk7JTbKY
# 2  Ignacio Corsini  07A5yehtSnoedViJAZkNnc
# 3  Ignacio Corsini  08FmqUhxtyLTn6pAh6bk45
# 4      Dick Haymes  08y9GfoqCWfOGsKdwojr5e

# %%
artists_exploded_enriched = artists_exploded.merge(df_genres, how = 'left', left_on = 'artists_upd',right_on = 'artists')
artists_exploded_enriched_nonnull = artists_exploded_enriched[~artists_exploded_enriched.genres_upd.isnull()]

# %%
artists_exploded_enriched.head()
# Out:
#        artists_upd                      id  \
# 0              Uli  35iwgR4jXetI318WEWsa1Q
# 1  Fernando Pessoa  021ht4sdgPcrDgSk7JTbKY
# 2  Ignacio Corsini  07A5yehtSnoedViJAZkNnc
# 3  Ignacio Corsini  08FmqUhxtyLTn6pAh6bk45
# 4      Dick Haymes  08y9GfoqCWfOGsKdwojr5e
#
#                                               genres          artists  \
# 0  ['corrido', 'nuevo regional mexicano', 'region...              Uli
# 1                                                NaN              NaN
# 2                         ['tango', 'vintage tango']  Ignacio Corsini
# 3                         ['tango', 'vintage tango']  Ignacio Corsini
# 4  ['adult standards', 'big band', 'deep adult st...      Dick Haymes
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.489667      0.588167  114746.500000  0.415332          0.815000
# 1           NaN           NaN            NaN       NaN               NaN
# 2      0.985169      0.545475  154560.711783  0.187842          0.425159
# 3      0.985169      0.545475  154560.711783  0.187842          0.425159
# 4      0.948967      0.313083  180499.216667  0.228717          0.325710
#
#    liveness   loudness  speechiness       tempo   valence  popularity   key  \
# 0  0.154917 -16.086833     0.249783   92.420000  0.263333    1.000000  10.0
# 1       NaN        NaN          NaN         NaN       NaN         NaN   NaN
# 2  0.182707 -20.862591     0.121051  106.514583  0.638670    0.031847   5.0
# 3  0.182707 -20.862591     0.121051  106.514583  0.638670    0.031847   5.0
# 4  0.229018 -13.666400     0.044527   97.144700  0.229657    6.050000   0.0
#
#    mode   count                                         genres_upd
# 0   1.0    12.0  [corrido, nuevo_regional_mexicano, regional_me...
# 1   NaN     NaN                                                NaN
# 2   1.0  1256.0                             [tango, vintage_tango]
# 3   1.0  1256.0                             [tango, vintage_tango]
# 4   1.0    60.0  [adult_standards, big_band, deep_adult_standar...

# %%
artists_exploded_enriched_nonnull[artists_exploded_enriched_nonnull['id'] =='6KuQTIu1KoTTkLXKrwlLPV']
# Out:
#             artists_upd                      id  \
# 5978    Robert Schumann  6KuQTIu1KoTTkLXKrwlLPV
# 5979  Vladimir Horowitz  6KuQTIu1KoTTkLXKrwlLPV
#
#                                                  genres            artists  \
# 5978  ['classical', 'early romantic era', 'german ro...    Robert Schumann
# 5979  ['classical', 'classical performance', 'classi...  Vladimir Horowitz
#
#       acousticness  danceability    duration_ms    energy  instrumentalness  \
# 5978      0.985304      0.362467  212896.341667  0.102329          0.783424
# 5979      0.990092      0.343624  266650.370833  0.118341          0.879898
#
#       liveness   loudness  speechiness      tempo   valence  popularity  key  \
# 5978  0.154049 -22.896354     0.047962  97.550958  0.274555    3.195833  5.0
# 5979  0.182788 -23.190868     0.043228  94.845258  0.224994    3.694167  1.0
#
#       mode   count                                         genres_upd
# 5978   1.0   240.0  [classical, early_romantic_era, german_romanti...
# 5979   1.0  1200.0  [classical, classical_performance, classical_p...

# %%
artists_genres_consolidated = artists_exploded_enriched_nonnull.groupby('id')['genres_upd'].apply(list).reset_index()

# %%
artists_genres_consolidated['consolidates_genre_lists'] = artists_genres_consolidated['genres_upd'].apply(lambda x: list(set(list(itertools.chain.from_iterable(x)))))

# %%
artists_genres_consolidated['consolidates_genre_lists'][0]
# Out:
# ['new_wave',
#  'candy_pop',
#  'permanent_wave',
#  'power_pop',
#  'rock',
#  'dance_rock',
#  'new_wave_pop']

# %%
artists_genres_consolidated['genres_upd'][0]
# Out:
# [['candy_pop',
#   'dance_rock',
#   'new_wave',
#   'new_wave_pop',
#   'permanent_wave',
#   'power_pop',
#   'rock']]

# %%
df = df.merge(artists_genres_consolidated[['id','consolidates_genre_lists']], on = 'id',how = 'left')

# %% [markdown]
# #### Here we have dataset of the tracks with consolidated genres in it and we are going to use this dataset for making recognition system

# %%
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4
#
#       artists_upd_v1 artists_upd_v2        artists_upd  \
# 0              [Uli]             []              [Uli]
# 1  [Fernando Pessoa]             []  [Fernando Pessoa]
# 2  [Ignacio Corsini]             []  [Ignacio Corsini]
# 3  [Ignacio Corsini]             []  [Ignacio Corsini]
# 4      [Dick Haymes]             []      [Dick Haymes]
#
#                                         artists_song  \
# 0                                           UliCarve
# 1  Fernando PessoaCapítulo 2.16 - Banquero Anarqu...
# 2  Ignacio CorsiniVivo para Quererte - Remasterizado
# 3       Ignacio CorsiniEl Prisionero - Remasterizado
# 4                     Dick HaymesLady of the Evening
#
#                             consolidates_genre_lists
# 0  [corrido, regional_mexican, sierreno, nuevo_re...
# 1                                                NaN
# 2                             [vintage_tango, tango]
# 3                             [vintage_tango, tango]
# 4  [swing, adult_standards, lounge, deep_adult_st...

# %%
## 2. Feature Engineering

### - Normalize float variables
### - OHE Year and Popularity Variables
### - Create TF-IDF features off of artist genres

# %% [markdown]
# ##### You can go through their explanation in the given links below:
#
# - [OHE EXPLANATION](https://www.geeksforgeeks.org/ml-one-hot-encoding-of-datasets-in-python/)
# - [TF-IDF EXPLANATION](https://towardsdatascience.com/tf-idf-for-document-ranking-from-scratch-in-python-on-real-world-dataset-796d339a4089#:~:text=TF%2DIDF%20stands%20for%20%E2%80%9CTerm,Information%20Retrieval%20and%20Text%20Mining.)

# %%
df.tail()
# Out:
#                             id                       name  popularity  \
# 523470  1ZwZsVZUiyFwIHMNpI3ERt                 Skyscraper           4
# 523471  5rgu12WBIHQtvej2MdHSH0                        云与海          50
# 523472  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 523473  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 523474  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
#
#         duration_ms  explicit                          artists  \
# 523470       106002         0                  ['Emilie Chin']
# 523471       258267         0                      ['阿YueYue']
# 523472       153293         0                   ['ROLE MODEL']
# 523473       187601         0                      ['FINNEAS']
# 523474       142003         0  ['Gentle Bones', 'Clara Benin']
#
#                                                id_artists release_date  \
# 523470                         ['4USdOnfLczwUglA3TrdHs2']   2020-02-08
# 523471                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 523472                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 523473                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 523474  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 523470         0.626   0.530    5   -13.117     0       0.0284         0.113
# 523471         0.560   0.518    0    -7.471     0       0.0292         0.785
# 523472         0.765   0.663    0    -5.223     1       0.0652         0.141
# 523473         0.535   0.314    7   -12.823     0       0.0408         0.895
# 523474         0.696   0.615   10    -6.212     1       0.0345         0.206
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 523470          0.856000    0.1040   0.2150  120.113               4
# 523471          0.000000    0.0648   0.2110  131.896               4
# 523472          0.000297    0.0924   0.6860  150.091               4
# 523473          0.000150    0.0874   0.0663  145.095               4
# 523474          0.000003    0.3050   0.4380   90.029               4
#
#                      artists_upd_v1 artists_upd_v2  \
# 523470                [Emilie Chin]             []
# 523471                    [阿YueYue]             []
# 523472                 [ROLE MODEL]             []
# 523473                    [FINNEAS]             []
# 523474  [Gentle Bones, Clara Benin]             []
#
#                         artists_upd                      artists_song  \
# 523470                [Emilie Chin]             Emilie ChinSkyscraper
# 523471                    [阿YueYue]                        阿YueYue云与海
# 523472                 [ROLE MODEL]                   ROLE MODELblind
# 523473                    [FINNEAS]  FINNEASWhat They'll Say About Us
# 523474  [Gentle Bones, Clara Benin]       Gentle BonesA Day At A Time
#
#                                  consolidates_genre_lists
# 523470                                                NaN
# 523471                                                NaN
# 523472  [bedroom_pop, alternative_r&b, pop, indie_pop,...
# 523473                         [la_indie, indie_pop, pop]
# 523474                                                NaN

# %%
df['year'] = df['release_date'].apply(lambda x: x.split('-')[0])

# %%
float_cols = df.dtypes[df.dtypes== 'float64'].index.values

# %%
ohe_cols = 'popularity'

# %%
df['popularity'].describe()
# Out:
# count    523475.000000
# mean         27.518993
# std          18.306436
# min           0.000000
# 25%          13.000000
# 50%          27.000000
# 75%          40.000000
# max         100.000000
# Name: popularity, dtype: float64

# %%
# create 5 point buckets for popularity 
df['popularity_red'] = df['popularity'].apply(lambda x: int(x/5))

# %%
# tfidf can't handle nulls so fill any null values with an empty list
df['consolidates_genre_lists'] = df['consolidates_genre_lists'].apply(lambda d: d if isinstance(d, list) else [])

# %%
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4
#
#       artists_upd_v1 artists_upd_v2        artists_upd  \
# 0              [Uli]             []              [Uli]
# 1  [Fernando Pessoa]             []  [Fernando Pessoa]
# 2  [Ignacio Corsini]             []  [Ignacio Corsini]
# 3  [Ignacio Corsini]             []  [Ignacio Corsini]
# 4      [Dick Haymes]             []      [Dick Haymes]
#
#                                         artists_song  \
# 0                                           UliCarve
# 1  Fernando PessoaCapítulo 2.16 - Banquero Anarqu...
# 2  Ignacio CorsiniVivo para Quererte - Remasterizado
# 3       Ignacio CorsiniEl Prisionero - Remasterizado
# 4                     Dick HaymesLady of the Evening
#
#                             consolidates_genre_lists  year  popularity_red
# 0  [corrido, regional_mexican, sierreno, nuevo_re...  1922               1
# 1                                                 []  1922               0
# 2                             [vintage_tango, tango]  1922               0
# 3                             [vintage_tango, tango]  1922               0
# 4  [swing, adult_standards, lounge, deep_adult_st...  1922               0

# %%
#simple function to create OHE features
#this gets passed later on
def ohe_prep(df, column, new_name): 
    """ 
    Create One Hot Encoded features of a specific column

    Parameters: 
        df (pandas dataframe): Spotify Dataframe
        column (str): Column to be processed
        new_name (str): new column name to be used
        
    Returns: 
        tf_df: One hot encoded features 
    """
    
    tf_df = pd.get_dummies(df[column])
    feature_names = tf_df.columns
    tf_df.columns = [new_name + "|" + str(i) for i in feature_names]
    tf_df.reset_index(drop = True, inplace = True)    
    return tf_df

# %%
#function to build entire feature set
def create_feature_set(df, float_cols):
    """ 
    Process spotify df to create a final set of features that will be used to generate recommendations

    Parameters: 
        df (pandas dataframe): Spotify Dataframe
        float_cols (list(str)): List of float columns that will be scaled 
        
    Returns: 
        final: final set of features 
    """
    
    #tfidf genre lists
    tfidf = TfidfVectorizer()
    tfidf_matrix =  tfidf.fit_transform(df['consolidates_genre_lists'].apply(lambda x: " ".join(x)))
    genre_df = pd.DataFrame(tfidf_matrix.toarray())
    genre_df.columns = ['genre' + "|" + i for i in tfidf.get_feature_names()]
    genre_df.reset_index(drop = True, inplace=True)

    #explicity_ohe = ohe_prep(df, 'explicit','exp')    
    year_ohe = ohe_prep(df, 'year','year') * 0.5
    popularity_ohe = ohe_prep(df, 'popularity_red','pop') * 0.15

    #scale float columns
    floats = df[float_cols].reset_index(drop = True)
    scaler = MinMaxScaler()
    floats_scaled = pd.DataFrame(scaler.fit_transform(floats), columns = floats.columns) * 0.2

    #concanenate all features
    final = pd.concat([genre_df, floats_scaled, popularity_ohe, year_ohe], axis = 1)
     
    #add song id
    final['id']=df['id'].values
    
    return final

# %% [markdown]
# ###### Since my system wasn't able to process on 523475 songs therefore slice the data to new songs (starts from 2010s)

# %%
dfs = df[400000:523475]  
# dfs.shape

# %%
complete_feature_set = create_feature_set(dfs, float_cols=float_cols)#.mean(axis = 0)

# %% [markdown]
# ##### The complete feature of our songs dataset which are really useful to us further

# %%
complete_feature_set.shape
# Out:
# (123475, 2227)

# %% [markdown]
# ## Spotify API Authorization
# ##### Here we are using spotify api to access the playlist of the user from which the model we get to know the taste of the user and will predict song according to his/her taste

# %%
#client id and secret for my application
client_id = 'b6221c7c43b0446999bbd1d314fd3f3f'
client_secret= 'e6a0b689efc546f2b44ba71b246106b1'

# %%
scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# token = util.prompt_for_user_token(scope, client_id= client_id, client_secret=client_secret, redirect_uri='http://www.google.com/')

# %%
token = 'BQAyOJ4iM76GwDRmJaq6N6lAAh75YMxOuGsPl_fIfCDlo2YHSKnNRNyGRgrCDmwepHgsv0WZm54DgtZom_0d1DS-0H8G0C8pQcZZWOjTkTKIYo-wQqYf3ZVFql3VydlSReQfNyiya6KSzgd3Ci5xfAjTny4IF765ZXOuuYlFhjRPIw3u&token_type=Bearer&expires_in=3600'

# %%
sp = spotipy.Spotify(auth=token)

# %%
#gather playlist names and images. 
#images aren't going to be used until I start building a UI
id_name = {}
list_photo = {}
for i in sp.current_user_playlists()['items']:

    id_name[i['name']] = i['uri'].split(':')[2]
    list_photo[i['uri'].split(':')[2]] = i['images'][0]['url']

# %% [markdown]
# ##### Playlists made by the user

# %%
id_name
# Out:
# {'Soothing Songs': '5mt3EQ4u7zAHnCiwoyfbUK',
#  'Vibrant songs': '1SY7HVB6dqBoRuEReOXKiY'}

# %%
def create_necessary_outputs(playlist_name,id_dic, df):
    """ 
    Pull songs from a specific playlist.

    Parameters: 
        playlist_name (str): name of the playlist you'd like to pull from the spotify API
        id_dic (dic): dictionary that maps playlist_name to playlist_id
        df (pandas dataframe): spotify datafram
        
    Returns: 
        playlist: all songs in the playlist THAT ARE AVAILABLE IN THE KAGGLE DATASET
    """
    
    #generate playlist dataframe
    playlist = pd.DataFrame()
    playlist_name = playlist_name

    for ix, i in enumerate(sp.playlist(id_dic[playlist_name])['tracks']['items']):
        #print(i['track']['artists'][0]['name'])
        playlist.loc[ix, 'artist'] = i['track']['artists'][0]['name']
        playlist.loc[ix, 'name'] = i['track']['name']
        playlist.loc[ix, 'id'] = i['track']['id'] # ['uri'].split(':')[2]
        playlist.loc[ix, 'url'] = i['track']['album']['images'][1]['url']
        playlist.loc[ix, 'date_added'] = i['added_at']

    playlist['date_added'] = pd.to_datetime(playlist['date_added'])  
    
    playlist = playlist[playlist['id'].isin(df['id'].values)].sort_values('date_added',ascending = False)
    
    return playlist

# %% [markdown]
# ###### We are going to work on his Soothing song playlist

# %%
playlist_vibrant = create_necessary_outputs('Soothing Songs', id_name,df)
#playlist_chill = create_necessary_outputs('chill',id_name, spotify_df)
#playlist_classical = create_necessary_outputs('Epic Classical',id_name, spotify_df)

# %%
from skimage import io
import matplotlib.pyplot as plt

def visualize_songs(df):
    """ 
    Visualize cover art of the songs in the inputted dataframe

    Parameters: 
        df (pandas dataframe): Playlist Dataframe
    """
    
    temp = df['url'].values
    plt.figure(figsize=(30, 2*int(len(temp))))
    columns = 4
    
    for i, url in enumerate(temp):
        plt.subplot(len(temp) / columns + 1, columns, i + 1)

        image = io.imread(url)
        plt.imshow(image)
        plt.xticks(color = 'w', fontsize = 0.1)
        plt.yticks(color = 'w', fontsize = 0.1)
        plt.xlabel(df['name'].values[i], fontsize = 20)
        plt.tight_layout(h_pad=0.5, w_pad=0.5)
        plt.subplots_adjust(wspace=None, hspace=None)

    plt.show()

# %% [markdown]
# ###### Songs in the soothing songs playlist

# %%
playlist_vibrant
# Out:
#                   artist                                              name  \
# 73                Pritam                       Ik Vaari Aa (From "Raabta")
# 72       Altamash Faridi                                        Ek Mulaqat
# 71          Falak Shabir                                            Ijazat
# 69          Arijit Singh                                Tere Hoke Rahengay
# 68                 Shaan                               Woh Ladki Hai Kahan
# 67                    KK                               Tu Hi Meri Shab Hai
# 66                Pritam                                             Safar
# 65     Shankar Mahadevan                                     Uff Teri Adaa
# 64          Arijit Singh  Main Dhoondne Ko Zamaane Mein (From "Heartless")
# 60          Ankit Tiwari                                       Boond Boond
# 59                Pritam                                        Tu Jo Mila
# 57             Lucky Ali                                            Hairat
# 56          Gulraj Singh                                          Pakeezah
# 55                Pritam                                        Hai Junoon
# 54        Clinton Cerejo                                          Hey Ya !
# 53          Amit Trivedi                                          Pashmina
# 52          Rochak Kohli                                 Mitti Di Khushboo
# 51                Pritam                                             Sajde
# 49                Pritam                                 Abhi Kuch Dino Se
# 48                Pritam                                    Aao Milo Chalo
# 47          Sachin-Jigar                                             Saibo
# 46        Gajendra Verma                   Mann Mera (From "Table No. 21")
# 45           Adnan Dhool                                             Awari
# 44        Salim Merchant                                         Aye Khuda
# 43                Pritam                                     Khudaya Khair
# 42                Pritam                                    Tu Hi Haqeeqat
# 41                Pritam                               Kya Mujhe Pyaar Hai
# 39            Atif Aslam                                             Aadat
# 38         Falak Shabbir                                            Saajna
# 36                Pritam                                              Kyon
# 35                Pritam                                          Aashiyan
# 34                Pritam                                   Saawali Si Raat
# 33                    KK                                         Abhi Abhi
# 32          Arijit Singh                   Tose Naina (From "Mickey Virus)
# 31  Rahat Fateh Ali Khan                                Dil To Bachcha Hai
# 30        Mohammed Irfan                                     Phir Mohabbat
# 28               Mithoon                                           Humnava
# 27            Ami Mishra                               Hasi - Male Version
# 21                    KK                                     Beete Lamhein
# 20          Kailash Kher                                           Saiyyan
# 18        Vishal Dadlani                                      Jee Le Zaraa
# 17    Shankar-Ehsaan-Loy                                        Tere Naina
# 16                Pritam                                  Teri Jhuki Nazar
# 15         Mustafa Zahid                                     Hum Jee Lenge
# 14         Mustafa Zahid                     Toh Phir Aao - Lounge Version
# 13         Mustafa Zahid                                  Tera Mera Rishta
# 12                Pritam                                         Tum Se Hi
# 11           A.R. Rahman                                      Kun Faya Kun
# 10           Tulsi Kumar                                      Masakali 2.0
# 9                 Pritam                                          Pee Loon
# 7              Ajay-Atul                                         O Saiyyan
# 5            Madan Mohan                                         Tere Liye
# 4              Lucky Ali                                           O Sanam
# 3                     KK                                 Dil Kyun Yeh Mera
# 2            A.R. Rahman                                         Tere Bina
# 1            A.R. Rahman                                  Jashn-E-Bahaaraa
#
#                         id                                                url  \
# 73  5lrA2NzUxmBjKr2tCZfMtl  https://i.scdn.co/image/ab67616d00001e02ece89c...
# 72  7DoMSoKN9uXj9okZMOSLpx  https://i.scdn.co/image/ab67616d00001e026b78c7...
# 71  6Gur6cgtBYPllKX2czvmWb  https://i.scdn.co/image/ab67616d00001e0274b90e...
# 69  0F4tFf7yriRbSK3Cw42z1t  https://i.scdn.co/image/ab67616d00001e02a87e24...
# 68  2tO0QPdCA0jgDBshTuYYkc  https://i.scdn.co/image/ab67616d00001e025da5e1...
# 67  4IGfpRPTnhzZyL74Ilubrb  https://i.scdn.co/image/ab67616d00001e022e42c0...
# 66  3BpaZLc6j9cBUsvnh5kinR  https://i.scdn.co/image/ab67616d00001e02a08a13...
# 65  0og9wKFGgFFNQnrBe7eisG  https://i.scdn.co/image/ab67616d00001e020e0eae...
# 64  43YkTTlOD203o9E5ZxhUjF  https://i.scdn.co/image/ab67616d00001e02c486f7...
# 60  3oKzTVB3MsspD89WtiLmX7  https://i.scdn.co/image/ab67616d00001e02f63710...
# 59  7txLCGOXyDlDXTjtR1Sk4v  https://i.scdn.co/image/ab67616d00001e02e7f1ff...
# 57  6512hyAQxOng8v4R71IV47  https://i.scdn.co/image/ab67616d00001e021da0a3...
# 56  3RAqJsgCOpwiPhkqmEvgI0  https://i.scdn.co/image/ab67616d00001e02e7a880...
# 55  5u4q3iqZ9IMbXaR7bsGYbW  https://i.scdn.co/image/ab67616d00001e02d567bc...
# 54  1qTh7hzjd361hjuzeaMFWK  https://i.scdn.co/image/ab67616d00001e020e0eae...
# 53  12Ud5p81gFX8feLUGpewfV  https://i.scdn.co/image/ab67616d00001e026c678e...
# 52  7tp4iYvcZksGp1u7feUrrO  https://i.scdn.co/image/ab67616d00001e024da67f...
# 51  4N66qcycDiFLJGjnXiKbKX  https://i.scdn.co/image/ab67616d00001e02d62e6f...
# 49  1QufGJee7k9v4Cfp2NxXbv  https://i.scdn.co/image/ab67616d00001e02b4e022...
# 48  6ocOeSjnWPcSTaSsi0zIdY  https://i.scdn.co/image/ab67616d00001e0252fe68...
# 47  6udC4b4jOSnHb9ItnXgKLR  https://i.scdn.co/image/ab67616d00001e021aac20...
# 46  2BeY2dQPbD8xYxx3yhBTVD  https://i.scdn.co/image/ab67616d00001e0242a659...
# 45  7IEww1rwWe1scos6rarOYh  https://i.scdn.co/image/ab67616d00001e02a2ef89...
# 44  1vgVsR5rkXGP4NmUcoroJH  https://i.scdn.co/image/ab67616d00001e0205ab1b...
# 43  2XYyriLyJSuGj4FN7QoNmM  https://i.scdn.co/image/ab67616d00001e02e2337c...
# 42  3OLFqbd9ZeVjaUKTiaLsD6  https://i.scdn.co/image/ab67616d00001e02bcb8ec...
# 41  3HFjh7QljnUCBLsoTwMuTj  https://i.scdn.co/image/ab67616d00001e02238513...
# 39  4yR2z3JafnCo86THA6ISZ4  https://i.scdn.co/image/ab67616d00001e02a2d9ae...
# 38  7KzGAwJRYS9KLMuVnStqYN  https://i.scdn.co/image/ab67616d00001e0222e2fd...
# 36  1sYC1fG7s4p0pTykrJqmgW  https://i.scdn.co/image/ab67616d00001e02352f44...
# 35  7ttlemwytO21npSmLKqTBg  https://i.scdn.co/image/ab67616d00001e02352f44...
# 34  4I5Xcdu5Hnki1aP0Uxbs4n  https://i.scdn.co/image/ab67616d00001e02352f44...
# 33  1tKhy83q8OsdcpZaX9N4Z2  https://i.scdn.co/image/ab67616d00001e02f1a179...
# 32  2fMlezwwP5Hr1UwuAknN4o  https://i.scdn.co/image/ab67616d00001e022d2263...
# 31  3EFGRGsshk0NWidcXfhKvw  https://i.scdn.co/image/ab67616d00001e0223ab22...
# 30  2b2HutIDmoeBnnKRWDLAtV  https://i.scdn.co/image/ab67616d00001e022432ed...
# 28  5lLRB1nnTy1p8nFaH1Vdyf  https://i.scdn.co/image/ab67616d00001e02b0f9ce...
# 27  32765xcLM1fd6wQIpkN9A0  https://i.scdn.co/image/ab67616d00001e02b0f9ce...
# 21  0zQa7QXLpUZfrrsWbgDZll  https://i.scdn.co/image/ab67616d00001e0251d1cd...
# 20  2vR23BjIzpLMtzsyKrM6Mb  https://i.scdn.co/image/ab67616d00001e02cd3f6c...
# 18  2r32XiAWtZbT3eLUvf4pag  https://i.scdn.co/image/ab67616d00001e02e8acd7...
# 17  1AXQ4ZCUueIfGGEYAdq9Pe  https://i.scdn.co/image/ab67616d00001e024ead13...
# 16  3beYHVCFKzbdNjJqjKeYpM  https://i.scdn.co/image/ab67616d00001e027e25e9...
# 15  1gekzL984xr4fbxVgVGQhC  https://i.scdn.co/image/ab67616d00001e027e25e9...
# 14  1Uw0T7EXu0r8lyXAdOklbK  https://i.scdn.co/image/ab67616d00001e02a72080...
# 13  0KSH21KbnIHHb1J4j8QrbY  https://i.scdn.co/image/ab67616d00001e02a72080...
# 12  7eQl3Yqv35ioqUfveKHitE  https://i.scdn.co/image/ab67616d00001e0252fe68...
# 11  7F8RNvTQlvbeBLeenycvN6  https://i.scdn.co/image/ab67616d00001e0254e544...
# 10  0LtuveFgRP4lkksywmCtxV  https://i.scdn.co/image/ab67616d00001e02e7d6e0...
# 9   52itZ0w0CydihB2JCZEIft  https://i.scdn.co/image/ab67616d00001e02df934f...
# 7   1sL8hnnZaB2Xzm1J66y4Tt  https://i.scdn.co/image/ab67616d00001e02b22e21...
# 5   3i11e2jzUtO3jChiFl3v9x  https://i.scdn.co/image/ab67616d00001e0296fa49...
# 4   5oYRr51VatOtkFeEOursuZ  https://i.scdn.co/image/ab67616d00001e027c8248...
# 3   5nHwX7e5XHnie22nuTFgda  https://i.scdn.co/image/ab67616d00001e02ae319e...
# 2   4FeczSomVWVyU4FW7xDeAI  https://i.scdn.co/image/ab67616d00001e020504fd...
# 1   1O5mTSQa0sCce9ghhDqIZl  https://i.scdn.co/image/ab67616d00001e0246131d...
#
#                   date_added
# 73 2020-11-29 17:17:33+00:00
# 72 2020-11-29 17:16:48+00:00
# 71 2020-11-29 17:16:17+00:00
# 69 2020-11-29 17:15:37+00:00
# 68 2020-11-29 17:15:27+00:00
# 67 2020-11-29 17:15:07+00:00
# 66 2020-11-29 17:13:23+00:00
# 65 2020-11-29 17:13:09+00:00
# 64 2020-11-29 17:12:49+00:00
# 60 2020-11-29 17:11:46+00:00
# 59 2020-11-29 17:11:35+00:00
# 57 2020-11-29 17:11:21+00:00
# 56 2020-11-29 17:11:04+00:00
# 55 2020-11-29 17:10:25+00:00
# 54 2020-11-29 17:09:28+00:00
# 53 2020-11-29 17:09:17+00:00
# 52 2020-11-29 17:08:57+00:00
# 51 2020-11-29 17:08:50+00:00
# 49 2020-11-29 17:08:26+00:00
# 48 2020-11-29 17:08:19+00:00
# 47 2020-11-29 17:08:07+00:00
# 46 2020-11-29 17:07:50+00:00
# 45 2020-11-29 17:07:46+00:00
# 44 2020-11-29 17:07:39+00:00
# 43 2020-11-29 17:07:34+00:00
# 42 2020-11-29 17:07:25+00:00
# 41 2020-11-29 17:06:08+00:00
# 39 2020-11-29 17:05:46+00:00
# 38 2020-11-29 17:05:40+00:00
# 36 2020-11-29 17:04:52+00:00
# 35 2020-11-29 17:04:46+00:00
# 34 2020-11-29 17:04:33+00:00
# 33 2020-11-29 17:04:18+00:00
# 32 2020-11-29 17:04:02+00:00
# 31 2020-11-29 17:02:42+00:00
# 30 2020-11-29 17:02:02+00:00
# 28 2020-11-29 17:01:52+00:00
# 27 2020-11-29 17:01:49+00:00
# 21 2020-11-29 16:59:29+00:00
# 20 2020-11-29 16:58:49+00:00
# 18 2020-11-29 16:58:25+00:00
# 17 2020-11-29 16:56:53+00:00
# 16 2020-11-29 16:56:41+00:00
# 15 2020-11-29 16:56:06+00:00
# 14 2020-11-29 16:56:00+00:00
# 13 2020-11-29 16:55:48+00:00
# 12 2020-11-29 16:55:12+00:00
# 11 2020-11-29 16:55:08+00:00
# 10 2020-11-29 16:55:03+00:00
# 9  2020-11-29 16:54:56+00:00
# 7  2020-11-29 16:54:14+00:00
# 5  2020-11-29 16:51:59+00:00
# 4  2020-11-29 16:51:26+00:00
# 3  2020-11-29 16:49:22+00:00
# 2  2020-11-29 16:45:33+00:00
# 1  2020-11-29 16:41:08+00:00

# %%
visualize_songs(playlist_vibrant)

# %% [markdown]
# ##### We are generating the features of the user playlist as we have done for the above dataset
# ###### We are doing this by just comparing the id of the song present in the user playlist with the id of the songs present in our dataset and naming them as complete_feature_set_playlist_vector(USER PLAYLIST FEATURE DF) and  complete_feature_set_nonplaylist(ORIGINAL DATASET FEATURE DF)

# %%
def generate_playlist_feature(complete_feature_set, playlist_df, weight_factor):
    """ 
    Summarize a user's playlist into a single vector

    Parameters: 
        complete_feature_set (pandas dataframe): Dataframe which includes all of the features for the spotify songs
        playlist_df (pandas dataframe): playlist dataframe
        weight_factor (float): float value that represents the recency bias. The larger the recency bias, the most priority recent songs get. Value should be close to 1. 
        
    Returns: 
        playlist_feature_set_weighted_final (pandas series): single feature that summarizes the playlist
        complete_feature_set_nonplaylist (pandas dataframe): 
    """
    
    complete_feature_set_playlist = complete_feature_set[complete_feature_set['id'].isin(playlist_df['id'].values)]#.drop('id', axis = 1).mean(axis =0)
    complete_feature_set_playlist = complete_feature_set_playlist.merge(playlist_df[['id','date_added']], on = 'id', how = 'inner')
    complete_feature_set_nonplaylist = complete_feature_set[~complete_feature_set['id'].isin(playlist_df['id'].values)]#.drop('id', axis = 1)
    
    playlist_feature_set = complete_feature_set_playlist.sort_values('date_added',ascending=False)

    most_recent_date = playlist_feature_set.iloc[0,-1]
    
    for ix, row in playlist_feature_set.iterrows():
        playlist_feature_set.loc[ix,'months_from_recent'] = int((most_recent_date.to_pydatetime() - row.iloc[-1].to_pydatetime()).days / 30)
        
    playlist_feature_set['weight'] = playlist_feature_set['months_from_recent'].apply(lambda x: weight_factor ** (-x))
    
    playlist_feature_set_weighted = playlist_feature_set.copy()
    #print(playlist_feature_set_weighted.iloc[:,:-4].columns)
    playlist_feature_set_weighted.update(playlist_feature_set_weighted.iloc[:,:-4].mul(playlist_feature_set_weighted.weight,0))
    playlist_feature_set_weighted_final = playlist_feature_set_weighted.iloc[:, :-4]
    #playlist_feature_set_weighted_final['id'] = playlist_feature_set['id']
    
    return playlist_feature_set_weighted_final.sum(axis = 0), complete_feature_set_nonplaylist

# %%
complete_feature_set_playlist_vector_EDM, complete_feature_set_nonplaylist_EDM = generate_playlist_feature(complete_feature_set, playlist_vibrant, 1.09)
#complete_feature_set_playlist_vector_chill, complete_feature_set_nonplaylist_chill = generate_playlist_feature(complete_feature_set, playlist_chill, 1.09)

# %%
complete_feature_set_playlist_vector_EDM.shape
# Out:
# (2226,)

# %% [markdown]
# #### Here we are finding the similar songs according to user playlist with the help of [COSINE SIMILARITY](https://towardsdatascience.com/understanding-cosine-similarity-and-its-application-fd42f585296a)

# %%
def generate_playlist_recos(df, features, nonplaylist_features):
    """ 
    Pull songs from a specific playlist.

    Parameters: 
        df (pandas dataframe): spotify dataframe
        features (pandas series): summarized playlist feature
        nonplaylist_features (pandas dataframe): feature set of songs that are not in the selected playlist
        
    Returns: 
        non_playlist_df_top_40: Top 40 recommendations for that playlist
    """
    
    non_playlist_df = df[df['id'].isin(nonplaylist_features['id'].values)]
    non_playlist_df['sim'] = cosine_similarity(nonplaylist_features.drop('id', axis = 1).values, features.values.reshape(1, -1))[:,0]
    non_playlist_df_top_40 = non_playlist_df.sort_values('sim',ascending = False).head(40)
    non_playlist_df_top_40['url'] = non_playlist_df_top_40['id'].apply(lambda x: sp.track(x)['album']['images'][1]['url'])
    
    return non_playlist_df_top_40

# %% [markdown]
# #### Here are the top 40 songs recommended by the model

# %%
edm_top40 = generate_playlist_recos(df, complete_feature_set_playlist_vector_EDM, complete_feature_set_nonplaylist_EDM)

# %%
edm_top40
# Out:
#                             id                                        name  \
# 473214  32R7r1j2r13XwF62fT8sNt                         Manasellam Mazhaiye
# 473173  4St20qfnH98z2CEY7Up5yn                                       Pungi
# 474061  0QkHR2PDC4c8OzbVPCJ10T  Mohe Rang Do Laal (From "Bajirao Mastani")
# 473787  4ZXsuOSu0vWtWMfmf1Gl3j                      Poolane Kunukeyamantaa
# 474094  5wCxdYvu4KU0S8wyxY0EQT              Pinga (From "Bajirao Mastani")
# 474142  1tghhViaNeUyYxqTDMteOb         Can't Forget You (Tujhe Bhula Diya)
# 473695  1fkjRQA8wXPPyxqYLbxuqy                                Ishq Bulaava
# 473223  3G2I8KB7bTWmvE1tHSlMHg                                     Laapata
# 473786  5AM51LU4hTpGSdQEFQmZTw                              Galat Baat Hai
# 473189  62wnQra2VgCUyHO3BUIAcr                             Jannatein Kahan
# 474106  5JlZLXvZBEFD9u8OoJq6Yh                         Girls Like To Swing
# 473186  2AAYoDgYtx5WCAg7Axeg70                                       Balma
# 473181  70O5Rpo2B2FB4B5bf68JWw                        Apnaa Mujhe Tu Lagaa
# 473210  1prGortu002OYC8sGfpAIj                                   Mashallah
# 473796  7xxxQG1BupSnOBo4qId9kl                                 Drama Queen
# 473127  2tva3nN2kQhBjHMC7Zlty6                        Deewana Kar Raha Hai
# 473197  73yIZXOY6Th386dlZTZLju    Mar Jayian Romantic (From "Vicky Donor")
# 473741  5Nuv6312XkkZd82AnnSc9g                Pookkalae Sattru Oyivedungal
# 473747  0JJjxzyDzlSh4hbZvtvqVl                     Tu Zaroori (From "Zid")
# 473165  7DbE178OOsJfJKyiNObOsw                                      Kukkad
# 473190  0sSapNABKrGwgaMhn0p8uL                                  Long Drive
# 473174  6wXPV6dNRAhFavrRaCdMXT                                      Challa
# 473750  6alNZoLuClM6yFv3GnRANk                               Mast Kalander
# 473758  1pwN1ldC7BTjip1hWQN6vJ                                 Caller Tune
# 474082  7hhuXHAyn4egzc3do1Oiqe                       Heer Toh Badi Sad Hai
# 473746  1FPhg4xpllC5P8lBDLMmfW                      Aathi (From "Kaththi")
# 473732  0mboVyI4R4MPH23yceAMz3                                    Hangover
# 474010  1kIaHdsk7dgJv11fANKeXg                                 Khoya Khoya
# 473355  6YgqRJRUkekXVwN8hRK2Zo               Dil Ibaadat (From "Tum Mile")
# 473727  3H43T5swYywvcdCBFiDgW6                                 Manwa Laage
# 473783  78R4fDeRrcoBIxL6uX4TnJ                              Mersalaayitten
# 473203  0koCvqji2k9Me2QJSjCzds                                      Lonely
# 474090  46mXuHxCjDiLoLPsqn24P8                             Shaam Shaandaar
# 473161  2VJIaxgWeyw9loL1sqKl7c                             Rab Ka Shukrana
# 473160  5ZLplBxO5OmotTmYY8920p                                Navrai Majhi
# 474056  5hRXhmEuQW3SJwX94BBV6u                                     Gulaabo
# 472634  3FS3ItpUATpALLi90uvkde                                I Am In Love
# 474033  0XCtA9pYB0aOciPzrJpkAK                                    Tu Chale
# 474011  2Rk3SdNdkxKopRotoio2iZ    Deewani Mastani (From "Bajirao Mastani")
# 473205  5Sif2EoFy6jvZ31s0wsB6Y                                Chup Chup Ke
#
#         popularity  duration_ms  explicit  \
# 473214          46       326495         0
# 473173          48       247827         0
# 474061          48       231838         0
# 473787          45       308107         0
# 474094          45       255169         0
# 474142          46       279771         0
# 473695          55       303640         0
# 473223          45       254851         0
# 473786          47       259627         0
# 473189          46       228093         0
# 474106          46       243166         0
# 473186          46       227578         0
# 473181          46       364019         0
# 473210          49       283376         0
# 473796          46       198747         0
# 473127          58       338923         0
# 473197          45       288960         0
# 473741          50       308162         0
# 473747          48       289707         0
# 473165          50       262867         0
# 473190          46       268443         0
# 473174          49       320418         0
# 473750          47       270669         0
# 473758          48       273100         0
# 474082          47       326792         0
# 473746          48       304924         0
# 473732          51       375552         0
# 474010          54       317075         0
# 473355          37       329307         0
# 473727          53       272083         0
# 473783          47       304000         0
# 473203          45       248868         0
# 474090          47       237464         0
# 473161          50       299573         0
# 473160          49       262827         0
# 474056          50       264418         0
# 472634          49       285109         0
# 474033          51       308485         0
# 474011          54       340232         0
# 473205          44       229652         0
#
#                                                   artists  \
# 473214       ['Sonu Nigam', 'Saindhavi', 'G. V. Prakash']
# 473173  ['Pritam', 'Mika Singh', 'Amitabh Bhattacharya...
# 474061                ['Shreya Ghoshal', 'Birju Maharaj']
# 473787    ['A.R. Rahman', 'Haricharan', 'Shreya Ghoshal']
# 474094                ['Shreya Ghoshal', 'Vaishali Made']
# 474142       ['Arjun', 'Jonita Gandhi', 'Vishal-Shekhar']
# 473695   ['Vishal-Shekhar', 'Sanam Puri', 'Shipra Goyal']
# 473223  ['Sohail Sen', 'KK', 'Palak Muchhal', 'Anvita ...
# 473786                       ['Neeti Mohan', 'Javed Ali']
# 473189                                   ['Pritam', 'KK']
# 474106                                ['Sunidhi Chauhan']
# 473186                      ['Shriram', 'Shreya Ghoshal']
# 473181                                     ['Sonu Nigam']
# 473210  ['Sajid-Wajid', 'Wajid', 'Shreya Ghoshal', 'Ka...
# 473796  ['Vishal-Shekhar', 'Shreya Ghoshal', 'Vishal D...
# 473127                                      ['Javed Ali']
# 473197              ['Vishal Dadlani', 'Sunidhi Chauhan']
# 473741    ['A.R. Rahman', 'Haricharan', 'Shreya Ghoshal']
# 473747  ['Shaarib Toshi', 'Sunidhi Chauhan', 'Sharib S...
# 473165  ['Vishal-Shekhar', 'Shahid Mallya', 'Nisha Mas...
# 473190                                     ['Mika Singh']
# 473174                 ['A.R. Rahman', 'Rabbi', 'Gulzar']
# 473750                ['Mika Singh', 'Yo Yo Honey Singh']
# 473758                 ['Neeraj Shridhar', 'Neeti Mohan']
# 474082                                     ['Mika Singh']
# 473746          ['Anirudh Ravichander', 'Vishal Dadlani']
# 473732  ['Salman Khan', 'Meet Bros Anjjan', 'Shreya Gh...
# 474010                 ['Mohit Chauhan', 'Priya Saraiya']
# 473355                                   ['Pritam', 'KK']
# 473727                 ['Shreya Ghoshal', 'Arijit Singh']
# 473783  ['A.R. Rahman', 'Anirudh Ravichander', 'Neeti ...
# 473203  ['Himesh Reshammiya', 'Yo Yo Honey Singh', 'Ha...
# 474090                                   ['Amit Trivedi']
# 473161                        ['Pritam', 'Mohit Chauhan']
# 473160  ['Sunidhi Chauhan', 'Natali Di Luccio', 'Neela...
# 474056                  ['Vishal Dadlani', 'Anusha Mani']
# 472634                      ['Pritam', 'KK', 'Dominique']
# 474033                 ['Arijit Singh', 'Shreya Ghoshal']
# 474011  ['Shreya Ghoshal', 'Altamash Faridi', 'Farhan ...
# 473205  ['Pritam', 'Shaan', 'Muazzam', 'Rizwan Ali Khan']
#
#                                                id_artists release_date  \
# 473214  ['1dVygo6tRFXC8CSWURQJq2', '6rEXjeIJ0wL6BFdo8C...   2012-10-26
# 473173  ['1wRPtKGflJrBx9BmLsSwlU', '5T2I75UlGBcWd5nVyf...   2012-02-24
# 474061  ['0oOet2f43PA68X5RxKobEy', '2hxDtWT09locLUsjCo...   2015-11-25
# 473787  ['1mYsTxnqsietFxj1OgoGbG', '1QvyquqkuuwUzdszyo...   2014-12-30
# 474094  ['0oOet2f43PA68X5RxKobEy', '3eD8Whpe2NYdslFWQf...   2015-11-16
# 474142  ['5tvfyAT4aOIOkumo6vw1yL', '00sCATpEvwH48ays7P...   2015-09-10
# 473695  ['6Mv8GjQa7LKUGCAqa9qqdb', '5kiKQJrz4BT7vFWVEC...   2014-01-05
# 473223  ['1bTROl5p3rGTpvKeWnGgrw', '4fEkbug6kZzzJ8eYX6...   2012-07-16
# 473786  ['3ZxZ03fj3tXBZHZWzvaLSM', '4W91bbPB2CTSsHwt7e...   2014-03-03
# 473189  ['1wRPtKGflJrBx9BmLsSwlU', '4fEkbug6kZzzJ8eYX6...   2012-03-30
# 474106                         ['3eDT9fwXKuHWFvgZaaYC5v']   2015-05-02
# 473186  ['3rhzPWhvEYewHykBuV6LFk', '0oOet2f43PA68X5RxK...   2012-10-30
# 473181                         ['1dVygo6tRFXC8CSWURQJq2']   2012-10-09
# 473210  ['3qdu3XhzSzkRhbwdFKnSuw', '6f5kUMXGROFtdAtxXZ...   2012-07-16
# 473796  ['6Mv8GjQa7LKUGCAqa9qqdb', '0oOet2f43PA68X5RxK...   2014-01-05
# 473127                         ['4W91bbPB2CTSsHwt7eqNl7']   2012-08-03
# 473197  ['6CXEwIaXYfVJ84biCxqc9k', '3eDT9fwXKuHWFvgZaa...   2012-04-04
# 473741  ['1mYsTxnqsietFxj1OgoGbG', '1QvyquqkuuwUzdszyo...   2014-09-18
# 473747  ['0FJz7XR37hH69traaHLijA', '3eDT9fwXKuHWFvgZaa...   2014-11-15
# 473165  ['6Mv8GjQa7LKUGCAqa9qqdb', '4LnYRxNZVCTsDCO2xK...   2012-08-31
# 473190                         ['5T2I75UlGBcWd5nVyfmL13']   2012-10-30
# 473174  ['1mYsTxnqsietFxj1OgoGbG', '4rD8zSLMVjpdgJyW14...   2012-10-09
# 473750  ['5T2I75UlGBcWd5nVyfmL13', '7uIbLdzzSEqnX0Pkrb...   2014-02-24
# 473758  ['3tHD07u1ON4uHxmnT9rwqZ', '3ZxZ03fj3tXBZHZWzv...   2014-04-27
# 474082                         ['5T2I75UlGBcWd5nVyfmL13']   2015-10-16
# 473746  ['4zCH9qm4R2DADamUHMCa6O', '6CXEwIaXYfVJ84biCx...   2014-09-18
# 473732  ['68ePdYvtRgq9CiPzv6fapI', '5isfxZ3RSdBlSLn3cS...   2014-07-07
# 474010  ['5GnnSrwNCGyfAU4zuIytiS', '6q29t5RuXxlBuqIZsO...   2015-08-14
# 473355  ['1wRPtKGflJrBx9BmLsSwlU', '4fEkbug6kZzzJ8eYX6...   2012-01-20
# 473727  ['0oOet2f43PA68X5RxKobEy', '4YRxDV8wJFPHPTeXep...   2014-09-26
# 473783  ['1mYsTxnqsietFxj1OgoGbG', '4zCH9qm4R2DADamUHM...   2014-09-18
# 473203  ['0sSxphmGskGCKlwB9xa6WU', '7uIbLdzzSEqnX0Pkrb...   2012-10-30
# 474090                         ['7HCqGPJcQTyGJ2yqntbuyr']   2015-10-22
# 473161  ['1wRPtKGflJrBx9BmLsSwlU', '5GnnSrwNCGyfAU4zuI...   2012-03-30
# 473160  ['3eDT9fwXKuHWFvgZaaYC5v', '672316o5Y63QCzOkXI...   2012-09-04
# 474056  ['6CXEwIaXYfVJ84biCxqc9k', '03yzClwzHK7M7wiQMQ...   2015-10-22
# 472634  ['1wRPtKGflJrBx9BmLsSwlU', '4fEkbug6kZzzJ8eYX6...   2010-06-29
# 474033  ['4YRxDV8wJFPHPTeXepOstw', '0oOet2f43PA68X5RxK...   2015-01-09
# 474011  ['0oOet2f43PA68X5RxKobEy', '38IHJBGBuaYXHEkIQd...   2015-11-25
# 473205  ['1wRPtKGflJrBx9BmLsSwlU', '5cB4d4jPYjMT326sji...   2012-10-09
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 473214         0.629   0.687   10    -4.624     0       0.0393        0.5920
# 473173         0.939   0.933   10    -2.688     1       0.0819        0.2350
# 474061         0.614   0.840    0    -3.291     1       0.0496        0.7480
# 473787         0.720   0.840    2    -5.049     1       0.0420        0.5910
# 474094         0.646   0.840    9    -3.753     1       0.1710        0.3940
# 474142         0.564   0.763   11    -2.975     0       0.0597        0.5320
# 473695         0.579   0.713    7    -7.334     1       0.0318        0.6170
# 473223         0.726   0.946   11    -6.490     0       0.0460        0.2160
# 473786         0.806   0.847    7    -3.640     1       0.0633        0.1350
# 473189         0.545   0.770    0    -6.102     1       0.0655        0.3080
# 474106         0.839   0.869    0    -3.005     1       0.1480        0.0817
# 473186         0.746   0.779    9    -4.175     1       0.0429        0.1890
# 473181         0.470   0.682    9    -3.854     0       0.0379        0.5860
# 473210         0.796   0.856    7    -8.154     1       0.0666        0.1530
# 473796         0.705   0.913    7    -6.709     1       0.0788        0.0137
# 473127         0.538   0.736   11    -6.113     0       0.1090        0.3700
# 473197         0.632   0.721    0    -7.616     0       0.0345        0.2040
# 473741         0.678   0.776    2    -5.827     1       0.0828        0.4460
# 473747         0.693   0.658    8    -5.875     0       0.0345        0.2800
# 473165         0.719   0.835    9    -7.391     1       0.0426        0.0902
# 473190         0.753   0.890    2    -5.022     1       0.1870        0.4400
# 473174         0.776   0.795    0    -5.454     1       0.0485        0.1210
# 473750         0.519   0.791    0    -5.737     0       0.0912        0.3660
# 473758         0.775   0.709    9    -3.835     0       0.1880        0.0344
# 474082         0.606   0.913    7    -4.976     1       0.0577        0.1070
# 473746         0.571   0.820    3    -5.232     0       0.0607        0.2160
# 473732         0.675   0.669    6    -4.878     0       0.0359        0.4120
# 474010         0.454   0.792    2    -5.851     1       0.1130        0.3290
# 473355         0.586   0.860    2    -5.025     0       0.0437        0.6410
# 473727         0.676   0.671    0    -6.271     1       0.0526        0.5680
# 473783         0.736   0.778   11    -6.728     0       0.0386        0.0246
# 473203         0.754   0.812    8    -6.260     1       0.1690        0.0732
# 474090         0.656   0.774    6    -4.406     0       0.0861        0.0304
# 473161         0.602   0.559   10    -6.203     0       0.0426        0.6150
# 473160         0.900   0.594    1    -7.274     1       0.0552        0.0764
# 474056         0.767   0.640   11    -6.626     1       0.1520        0.0960
# 472634         0.702   0.694    2    -5.740     1       0.0286        0.6850
# 474033         0.612   0.782    2    -6.848     1       0.0702        0.2800
# 474011         0.356   0.865    1    -3.388     0       0.0663        0.4790
# 473205         0.691   0.738    9    -5.922     1       0.0865        0.7110
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 473214          0.000048    0.1060    0.762  170.006               4
# 473173          0.000001    0.0293    0.708  122.994               4
# 474061          0.000000    0.0531    0.497  131.760               3
# 473787          0.000001    0.1500    0.680   85.995               4
# 474094          0.000000    0.1830    0.818   95.076               4
# 474142          0.000000    0.1110    0.485  139.839               4
# 473695          0.000033    0.1180    0.635  159.915               3
# 473223          0.016900    0.1630    0.869  108.021               4
# 473786          0.000026    0.0833    0.804  123.967               4
# 473189          0.000028    0.1670    0.696  159.975               4
# 474106          0.000000    0.3230    0.605  125.026               4
# 473186          0.003070    0.0923    0.767  117.891               4
# 473181          0.000000    0.0955    0.499  159.991               4
# 473210          0.000011    0.3110    0.864  109.979               4
# 473796          0.000000    0.3290    0.955  145.948               4
# 473127          0.000000    0.1240    0.644  147.890               4
# 473197          0.000010    0.1020    0.808  145.938               4
# 473741          0.000000    0.1270    0.625   85.942               4
# 473747          0.001920    0.1070    0.922  103.005               4
# 473165          0.004310    0.3310    0.961  139.985               4
# 473190          0.000007    0.0854    0.283   87.015               4
# 473174          0.000000    0.1380    0.569  117.989               4
# 473750          0.000000    0.1140    0.510  111.065               4
# 473758          0.000000    0.1040    0.858  127.075               4
# 474082          0.000012    0.0993    0.881   90.998               4
# 473746          0.000000    0.6850    0.461  150.037               4
# 473732          0.000000    0.2100    0.618   90.027               4
# 474010          0.000038    0.4460    0.450  174.017               4
# 473355          0.000000    0.2680    0.665  149.968               4
# 473727          0.000000    0.0885    0.572   81.046               4
# 473783          0.001740    0.0533    0.837  125.999               4
# 473203          0.000000    0.6090    0.492  128.010               4
# 474090          0.001050    0.0494    0.636  133.995               4
# 473161          0.000000    0.1310    0.440  122.017               4
# 473160          0.000030    0.0718    0.816  120.038               4
# 474056          0.000044    0.0850    0.751  146.036               4
# 472634          0.000060    0.1680    0.760  130.024               4
# 474033          0.000000    0.1870    0.600   85.967               4
# 474011          0.000000    0.2030    0.567   79.947               4
# 473205          0.000000    0.3970    0.871   90.033               4
#
#                                            artists_upd_v1  \
# 473214             [Sonu Nigam, Saindhavi, G. V. Prakash]
# 473173  [Pritam, Mika Singh, Amitabh Bhattacharya, Nak...
# 474061                    [Shreya Ghoshal, Birju Maharaj]
# 473787          [A.R. Rahman, Haricharan, Shreya Ghoshal]
# 474094                    [Shreya Ghoshal, Vaishali Made]
# 474142             [Arjun, Jonita Gandhi, Vishal-Shekhar]
# 473695         [Vishal-Shekhar, Sanam Puri, Shipra Goyal]
# 473223       [Sohail Sen, KK, Palak Muchhal, Anvita Dutt]
# 473786                           [Neeti Mohan, Javed Ali]
# 473189                                       [Pritam, KK]
# 474106                                  [Sunidhi Chauhan]
# 473186                          [Shriram, Shreya Ghoshal]
# 473181                                       [Sonu Nigam]
# 473210  [Sajid-Wajid, Wajid, Shreya Ghoshal, Kausar Mu...
# 473796   [Vishal-Shekhar, Shreya Ghoshal, Vishal Dadlani]
# 473127                                        [Javed Ali]
# 473197                  [Vishal Dadlani, Sunidhi Chauhan]
# 473741          [A.R. Rahman, Haricharan, Shreya Ghoshal]
# 473747     [Shaarib Toshi, Sunidhi Chauhan, Sharib Sabri]
# 473165  [Vishal-Shekhar, Shahid Mallya, Nisha Mascaren...
# 473190                                       [Mika Singh]
# 473174                       [A.R. Rahman, Rabbi, Gulzar]
# 473750                    [Mika Singh, Yo Yo Honey Singh]
# 473758                     [Neeraj Shridhar, Neeti Mohan]
# 474082                                       [Mika Singh]
# 473746              [Anirudh Ravichander, Vishal Dadlani]
# 473732    [Salman Khan, Meet Bros Anjjan, Shreya Ghoshal]
# 474010                     [Mohit Chauhan, Priya Saraiya]
# 473355                                       [Pritam, KK]
# 473727                     [Shreya Ghoshal, Arijit Singh]
# 473783    [A.R. Rahman, Anirudh Ravichander, Neeti Mohan]
# 473203  [Himesh Reshammiya, Yo Yo Honey Singh, Hamsika...
# 474090                                     [Amit Trivedi]
# 473161                            [Pritam, Mohit Chauhan]
# 473160  [Sunidhi Chauhan, Natali Di Luccio, Neelambari...
# 474056                      [Vishal Dadlani, Anusha Mani]
# 472634                            [Pritam, KK, Dominique]
# 474033                     [Arijit Singh, Shreya Ghoshal]
# 474011  [Shreya Ghoshal, Altamash Faridi, Farhan Sabri...
# 473205          [Pritam, Shaan, Muazzam, Rizwan Ali Khan]
#
#                  artists_upd_v2  \
# 473214                       []
# 473173                       []
# 474061                       []
# 473787                       []
# 474094                       []
# 474142                       []
# 473695                       []
# 473223                       []
# 473786                       []
# 473189                       []
# 474106                       []
# 473186                       []
# 473181                       []
# 473210                       []
# 473796                       []
# 473127                       []
# 473197                       []
# 473741                       []
# 473747                       []
# 473165  [Marianne D'cruz Aiman]
# 473190                       []
# 473174                       []
# 473750                       []
# 473758                       []
# 474082                       []
# 473746                       []
# 473732                       []
# 474010                       []
# 473355                       []
# 473727                       []
# 473783                       []
# 473203                       []
# 474090                       []
# 473161                       []
# 473160                       []
# 474056                       []
# 472634                       []
# 474033                       []
# 474011                       []
# 473205                       []
#
#                                               artists_upd  \
# 473214             [Sonu Nigam, Saindhavi, G. V. Prakash]
# 473173  [Pritam, Mika Singh, Amitabh Bhattacharya, Nak...
# 474061                    [Shreya Ghoshal, Birju Maharaj]
# 473787          [A.R. Rahman, Haricharan, Shreya Ghoshal]
# 474094                    [Shreya Ghoshal, Vaishali Made]
# 474142             [Arjun, Jonita Gandhi, Vishal-Shekhar]
# 473695         [Vishal-Shekhar, Sanam Puri, Shipra Goyal]
# 473223       [Sohail Sen, KK, Palak Muchhal, Anvita Dutt]
# 473786                           [Neeti Mohan, Javed Ali]
# 473189                                       [Pritam, KK]
# 474106                                  [Sunidhi Chauhan]
# 473186                          [Shriram, Shreya Ghoshal]
# 473181                                       [Sonu Nigam]
# 473210  [Sajid-Wajid, Wajid, Shreya Ghoshal, Kausar Mu...
# 473796   [Vishal-Shekhar, Shreya Ghoshal, Vishal Dadlani]
# 473127                                        [Javed Ali]
# 473197                  [Vishal Dadlani, Sunidhi Chauhan]
# 473741          [A.R. Rahman, Haricharan, Shreya Ghoshal]
# 473747     [Shaarib Toshi, Sunidhi Chauhan, Sharib Sabri]
# 473165  [Vishal-Shekhar, Shahid Mallya, Nisha Mascaren...
# 473190                                       [Mika Singh]
# 473174                       [A.R. Rahman, Rabbi, Gulzar]
# 473750                    [Mika Singh, Yo Yo Honey Singh]
# 473758                     [Neeraj Shridhar, Neeti Mohan]
# 474082                                       [Mika Singh]
# 473746              [Anirudh Ravichander, Vishal Dadlani]
# 473732    [Salman Khan, Meet Bros Anjjan, Shreya Ghoshal]
# 474010                     [Mohit Chauhan, Priya Saraiya]
# 473355                                       [Pritam, KK]
# 473727                     [Shreya Ghoshal, Arijit Singh]
# 473783    [A.R. Rahman, Anirudh Ravichander, Neeti Mohan]
# 473203  [Himesh Reshammiya, Yo Yo Honey Singh, Hamsika...
# 474090                                     [Amit Trivedi]
# 473161                            [Pritam, Mohit Chauhan]
# 473160  [Sunidhi Chauhan, Natali Di Luccio, Neelambari...
# 474056                      [Vishal Dadlani, Anusha Mani]
# 472634                            [Pritam, KK, Dominique]
# 474033                     [Arijit Singh, Shreya Ghoshal]
# 474011  [Shreya Ghoshal, Altamash Faridi, Farhan Sabri...
# 473205          [Pritam, Shaan, Muazzam, Rizwan Ali Khan]
#
#                                              artists_song  \
# 473214                      Sonu NigamManasellam Mazhaiye
# 473173                                        PritamPungi
# 474061  Shreya GhoshalMohe Rang Do Laal (From "Bajirao...
# 473787                  A.R. RahmanPoolane Kunukeyamantaa
# 474094       Shreya GhoshalPinga (From "Bajirao Mastani")
# 474142           ArjunCan't Forget You (Tujhe Bhula Diya)
# 473695                         Vishal-ShekharIshq Bulaava
# 473223                                  Sohail SenLaapata
# 473786                          Neeti MohanGalat Baat Hai
# 473189                              PritamJannatein Kahan
# 474106                 Sunidhi ChauhanGirls Like To Swing
# 473186                                       ShriramBalma
# 473181                     Sonu NigamApnaa Mujhe Tu Lagaa
# 473210                               Sajid-WajidMashallah
# 473796                          Vishal-ShekharDrama Queen
# 473127                      Javed AliDeewana Kar Raha Hai
# 473197  Vishal DadlaniMar Jayian Romantic (From "Vicky...
# 473741            A.R. RahmanPookkalae Sattru Oyivedungal
# 473747               Shaarib ToshiTu Zaroori (From "Zid")
# 473165                               Vishal-ShekharKukkad
# 473190                               Mika SinghLong Drive
# 473174                                  A.R. RahmanChalla
# 473750                            Mika SinghMast Kalander
# 473758                         Neeraj ShridharCaller Tune
# 474082                    Mika SinghHeer Toh Badi Sad Hai
# 473746          Anirudh RavichanderAathi (From "Kaththi")
# 473732                                Salman KhanHangover
# 474010                           Mohit ChauhanKhoya Khoya
# 473355                PritamDil Ibaadat (From "Tum Mile")
# 473727                          Shreya GhoshalManwa Laage
# 473783                          A.R. RahmanMersalaayitten
# 473203                            Himesh ReshammiyaLonely
# 474090                        Amit TrivediShaam Shaandaar
# 473161                              PritamRab Ka Shukrana
# 473160                        Sunidhi ChauhanNavrai Majhi
# 474056                              Vishal DadlaniGulaabo
# 472634                                 PritamI Am In Love
# 474033                               Arijit SinghTu Chale
# 474011  Shreya GhoshalDeewani Mastani (From "Bajirao M...
# 473205                                 PritamChup Chup Ke
#
#                          consolidates_genre_lists  year  popularity_red  \
# 473214  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473173  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 474061  [modern_bollywood, desi_pop, filmi, sufi]  2015               9
# 473787  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 474094  [modern_bollywood, desi_pop, filmi, sufi]  2015               9
# 474142  [modern_bollywood, desi_pop, filmi, sufi]  2015               9
# 473695  [modern_bollywood, desi_pop, filmi, sufi]  2014              11
# 473223  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473786  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 473189  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 474106  [modern_bollywood, desi_pop, filmi, sufi]  2015               9
# 473186  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473181  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473210  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473796  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 473127  [modern_bollywood, desi_pop, filmi, sufi]  2012              11
# 473197  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473741  [modern_bollywood, desi_pop, filmi, sufi]  2014              10
# 473747  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 473165  [modern_bollywood, desi_pop, filmi, sufi]  2012              10
# 473190  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473174  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 473750  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 473758  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 474082  [modern_bollywood, desi_pop, filmi, sufi]  2015               9
# 473746  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 473732  [modern_bollywood, desi_pop, filmi, sufi]  2014              10
# 474010  [modern_bollywood, desi_pop, filmi, sufi]  2015              10
# 473355  [modern_bollywood, desi_pop, filmi, sufi]  2012               7
# 473727  [modern_bollywood, desi_pop, filmi, sufi]  2014              10
# 473783  [modern_bollywood, desi_pop, filmi, sufi]  2014               9
# 473203  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 474090  [modern_bollywood, desi_pop, filmi, sufi]  2015               9
# 473161  [modern_bollywood, desi_pop, filmi, sufi]  2012              10
# 473160  [modern_bollywood, desi_pop, filmi, sufi]  2012               9
# 474056  [modern_bollywood, desi_pop, filmi, sufi]  2015              10
# 472634  [modern_bollywood, desi_pop, filmi, sufi]  2010               9
# 474033  [modern_bollywood, desi_pop, filmi, sufi]  2015              10
# 474011  [modern_bollywood, desi_pop, filmi, sufi]  2015              10
# 473205  [modern_bollywood, desi_pop, filmi, sufi]  2012               8
#
#              sim                                                url
# 473214  0.885491  https://i.scdn.co/image/ab67616d00001e02b3fa39...
# 473173  0.885086  https://i.scdn.co/image/ab67616d00001e02e810a8...
# 474061  0.884906  https://i.scdn.co/image/ab67616d00001e02c78512...
# 473787  0.884009  https://i.scdn.co/image/ab67616d00001e02006e0d...
# 474094  0.882932  https://i.scdn.co/image/ab67616d00001e025eb3e6...
# 474142  0.882546  https://i.scdn.co/image/ab67616d00001e028e09c5...
# 473695  0.882481  https://i.scdn.co/image/ab67616d00001e022025db...
# 473223  0.882332  https://i.scdn.co/image/ab67616d00001e02c52900...
# 473786  0.881926  https://i.scdn.co/image/ab67616d00001e0240c985...
# 473189  0.881482  https://i.scdn.co/image/ab67616d00001e02d215b5...
# 474106  0.881267  https://i.scdn.co/image/ab67616d00001e02cff978...
# 473186  0.880844  https://i.scdn.co/image/ab67616d00001e0233f89b...
# 473181  0.880835  https://i.scdn.co/image/ab67616d00001e02872577...
# 473210  0.880727  https://i.scdn.co/image/ab67616d00001e02c52900...
# 473796  0.880132  https://i.scdn.co/image/ab67616d00001e022025db...
# 473127  0.879819  https://i.scdn.co/image/ab67616d00001e02e108cd...
# 473197  0.879279  https://i.scdn.co/image/ab67616d00001e02e079fc...
# 473741  0.878789  https://i.scdn.co/image/ab67616d00001e02809bf7...
# 473747  0.878784  https://i.scdn.co/image/ab67616d00001e026d1b24...
# 473165  0.878684  https://i.scdn.co/image/ab67616d00001e02ad40f4...
# 473190  0.878627  https://i.scdn.co/image/ab67616d00001e0233f89b...
# 473174  0.878564  https://i.scdn.co/image/ab67616d00001e021efbf8...
# 473750  0.878130  https://i.scdn.co/image/ab67616d00001e0294b6ef...
# 473758  0.877847  https://i.scdn.co/image/ab67616d00001e0283f14e...
# 474082  0.877666  https://i.scdn.co/image/ab67616d00001e02da5089...
# 473746  0.877629  https://i.scdn.co/image/ab67616d00001e02579e22...
# 473732  0.877571  https://i.scdn.co/image/ab67616d00001e02232bad...
# 474010  0.877362  https://i.scdn.co/image/ab67616d00001e02f4784b...
# 473355  0.877224  https://i.scdn.co/image/ab67616d00001e0261e2c7...
# 473727  0.877127  https://i.scdn.co/image/ab67616d00001e02295f7a...
# 473783  0.876910  https://i.scdn.co/image/ab67616d00001e02809bf7...
# 473203  0.876487  https://i.scdn.co/image/ab67616d00001e0233f89b...
# 474090  0.876359  https://i.scdn.co/image/ab67616d00001e02339472...
# 473161  0.875956  https://i.scdn.co/image/ab67616d00001e02d215b5...
# 473160  0.875875  https://i.scdn.co/image/ab67616d00001e02ff4aa9...
# 474056  0.875679  https://i.scdn.co/image/ab67616d00001e02339472...
# 472634  0.875505  https://i.scdn.co/image/ab67616d00001e02df934f...
# 474033  0.875467  https://i.scdn.co/image/ab67616d00001e02a4686f...
# 474011  0.875412  https://i.scdn.co/image/ab67616d00001e02c78512...
# 473205  0.875351  https://i.scdn.co/image/ab67616d00001e02d78210...

# %%
visualize_songs(edm_top40)
